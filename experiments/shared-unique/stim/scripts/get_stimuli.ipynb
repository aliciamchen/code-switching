# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
chat = pd.read_csv('../boyce_data/filtered_chat.csv').reset_index().rename(columns={'level_0': 'chat_idx'})
chat.head()
# Out:
#    chat_idx             row_id  index                             stageIds  \
# 0         0  7hkQitvpzWzLYmqsQ      0  oHJqKk7mnHQXxo6bR,Pn38JXdLSF3jWmBR3
# 1         1  7hkQitvpzWzLYmqsQ      0  oHJqKk7mnHQXxo6bR,Pn38JXdLSF3jWmBR3
# 2         2  7hkQitvpzWzLYmqsQ      0  oHJqKk7mnHQXxo6bR,Pn38JXdLSF3jWmBR3
# 3         3  tywCoAdX8FZS6pxkb      1  c2iyJTYwsrXsGAGfL,LXoXMwkLzxoyR3Pfk
# 4         4  tywCoAdX8FZS6pxkb      1  c2iyJTYwsrXsGAGfL,LXoXMwkLzxoyR3Pfk
#
#               gameId             createdAt  targetNum  repNum  trialNum  \
# 0  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          0       0         0
# 1  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          0       0         0
# 2  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          0       0         0
# 3  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          1       0         1
# 4  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          1       0         1
#
#    numPlayers                                               text  \
# 0           4            ok so its kind of like a dog lying down
# 1           4  its a long shape on the bottom of the square w...
# 2           4                          fully down or streching ?
# 3           4  ok so its like a guy sort of crouching with hi...
# 4           4               idk how to describe stuff good sorry
#
#             playerId                     target      role  countCorrect  \
# 0  qZYMtuyj2SBfZk8XH  /experiment/tangram_G.png   speaker           0.0
# 1  qZYMtuyj2SBfZk8XH  /experiment/tangram_G.png   speaker           0.0
# 2  ieBYKaxXNCy2QcwJj  /experiment/tangram_G.png  listener           0.0
# 3  qZYMtuyj2SBfZk8XH  /experiment/tangram_L.png   speaker           3.0
# 4  qZYMtuyj2SBfZk8XH  /experiment/tangram_L.png   speaker           3.0
#
#              speaker submitted  \
# 0  qZYMtuyj2SBfZk8XH      True
# 1  qZYMtuyj2SBfZk8XH      True
# 2  qZYMtuyj2SBfZk8XH      True
# 3  qZYMtuyj2SBfZk8XH      True
# 4  qZYMtuyj2SBfZk8XH      True
#
#                                         spellchecked is.chitchat
# 0           ok so it's kind of like a dog lying down       False
# 1  it's a long shape on the bottom of the square ...       False
# 2                         fully down or stretching ?       False
# 3  ok so it's like a guy sort of crouching with h...       False
# 4                                                NaN        True

# %%
# How many participants?
print(chat['playerId'].nunique())

# How many games?
print(chat['gameId'].nunique())
# Out:
# 416
# 107

# %% [markdown]
# Filter for games
#
# View games and see what tangrams converged

# %%
speaker_rep4 = chat[
    (chat["role"] == "speaker")
    & (chat["repNum"] == 5)
    & (chat["numPlayers"] == 4)
    & (chat["is.chitchat"] == False)
    & (chat["target"] == "/experiment/tangram_L.png")
    & (chat["countCorrect"] > 1)
]
speaker_rep4
# Out:
#        chat_idx             row_id  index  \
# 239         239  FrYMnCz7oPKHpEcKK     65
# 415         415  L8T5vtE4uH5bSzZjs     60
# 588         588  8EFd4pNoJkG3bH9PT     63
# 589         589  8EFd4pNoJkG3bH9PT     63
# 782         782  nXQdJ7oqL7nzk5G4B     64
# 3475       3475  za6gwcTWPTfsftd8e     64
# 3795       3795  RcpAQ48MYLi4HrKJN     70
# 3796       3796  RcpAQ48MYLi4HrKJN     70
# 4131       4131  uBvYFXsSmCnDPrsza     67
# 4692       4692  N23TR9nkgNxFPPFgc     71
# 4693       4693  N23TR9nkgNxFPPFgc     71
# 4695       4695  N23TR9nkgNxFPPFgc     71
# 11375                                        Legs behind  Za93y7uusM9q8x2fY
# 11513                              Begging facing right.  CYJgWvH9gDvTupk6Y
# 11631                        kneeling with tray on right  tnNKrEsyuarajKSEw
#
#                           target     role  countCorrect            speaker  \
# 239    /experiment/tangram_K.png  speaker           3.0  ieBYKaxXNCy2QcwJj
# 415    /experiment/tangram_K.png  speaker           3.0  ZvhRyXkvKz6ES5HwX
# 588    /experiment/tangram_K.png  speaker           3.0  KDECwB9Cikjj7ZsE9
# 589    /experiment/tangram_K.png  speaker           3.0  KDECwB9Cikjj7ZsE9
# 782    /experiment/tangram_K.png  speaker           3.0  c9T7t2RNEHdtaipbh
# 3475   /experiment/tangram_K.png  speaker           3.0  kLzigdBtkD7wevtco
# 3795   /experiment/tangram_K.png  speaker           3.0  DJMWzKpmH3hrQTzWH
# 3796   /experiment/tangram_K.png  speaker           3.0  DJMWzKpmH3hrQTzWH
# 4131   /experiment/tangram_K.png  speaker           3.0  mKtcij3NPdyCXiLFo
# 4692   /experiment/tangram_K.png  speaker           3.0  aWXqkafSBD9Ty7ZCa
# 4693   /experiment/tangram_K.png  speaker           3.0  aWXqkafSBD9Ty7ZCa
# 4695   /experiment/tangram_K.png  speaker           3.0  aWXqkafSBD9Ty7ZCa
# 4696   /experiment/tangram_K.png  speaker           3.0  aWXqkafSBD9Ty7ZCa
# 4699   /experiment/tangram_K.png  speaker           3.0  aWXqkafSBD9Ty7ZCa
# 4972   /experiment/tangram_K.png  speaker           3.0  f4yCdS7r3GCeu2Jan
# 4973   /experiment/tangram_K.png  speaker           3.0  f4yCdS7r3GCeu2Jan
# 5262   /experiment/tangram_K.png  speaker           2.0  fnpWjeJ5eoBme4DLX
# 6528   /experiment/tangram_K.png  speaker           3.0  Y3ATEvaw2Ex9TyTaM
# 6529   /experiment/tangram_K.png  speaker           3.0  Y3ATEvaw2Ex9TyTaM
# 6795   /experiment/tangram_K.png  speaker           2.0  wzhhQtjp6x8rGAv7f
# 6797   /experiment/tangram_K.png  speaker           2.0  wzhhQtjp6x8rGAv7f
# 6799   /experiment/tangram_K.png  speaker           2.0  wzhhQtjp6x8rGAv7f
# 6802   /experiment/tangram_K.png  speaker           2.0  wzhhQtjp6x8rGAv7f
# 7131   /experiment/tangram_K.png  speaker           2.0  PTgQgdtPBpeZAgKSJ
# 7139   /experiment/tangram_K.png  speaker           2.0  PTgQgdtPBpeZAgKSJ
# 7463   /experiment/tangram_K.png  speaker           3.0  YisDn9qApPgZZysmj
# 7464   /experiment/tangram_K.png  speaker           3.0  YisDn9qApPgZZysmj
# 7652   /experiment/tangram_K.png  speaker           3.0  tSSE6WrrX5B6873NB
# 7653   /experiment/tangram_K.png  speaker           3.0  tSSE6WrrX5B6873NB
# 11181  /experiment/tangram_K.png  speaker           2.0  zfkDAvY8mpzxyfDYN
# 11374  /experiment/tangram_K.png  speaker           3.0  Za93y7uusM9q8x2fY
# 11375  /experiment/tangram_K.png  speaker           3.0  Za93y7uusM9q8x2fY
# 11513  /experiment/tangram_K.png  speaker           2.0  CYJgWvH9gDvTupk6Y
# 11631  /experiment/tangram_K.png  speaker           2.0  tnNKrEsyuarajKSEw
#
#       submitted                                       spellchecked is.chitchat
# 239        True                                               duck       False
# 415        True                                   kneeling speaker       False
# 588        True                                    Kneeling prayer       False
# 589        True                                     on their knees       False
# 782        True    kneeling heals up at the back, triangle on back       False
# 3475       True     person kneeling to right this time with a tail       False
# 3795       True                              kneeling to the right       False
# 3796       True                       diamond head on diamond body       False
# 4131       True        fully knelt, triangle sticking up from left       False
# 4692       True                                       kneeling man       False
# 4693       True                  perfect diamond shape of his head       False
# 4695       True                          arms pointed to the right       False
# 4696       True                                         knees also       False
# 4699       True                                    pointed upwards       False
# 4972       True                            woman with tail on left       False
# 4973       True                       hands and knees facing right       False
# 5262       True  facing right, praying position, feet pointed u...       False
# 6528       True                person kneeling facing to the right       False
# 6529       True  on their knees with a triangle pointing to the...       False
# 6795       True  facing to the right, offering, knees bent, fee...       False
# 6797       True                                                NaN       False
# 6799       True                                           arms out       False
# 6802       True                                      two triangles       False
# 7131       True              beggar on his knees, foot on the left       False
# 7139       True                            right angle on the left       False
# 7463       True                  man bend down, flick on left side       False
# 7464       True                              arms out to the right       False
# 7652       True                        woman kneeling facing right       False
# 7653       True                                      arms held out       False
# 11181      True  like a person in a robe kneeling to the right,...       False
# 11374      True                                            Praying       False
# 11375      True                                        Legs behind       False
# 11513      True                              Begging facing right.       False
# 11631      True                        kneeling with tray on right       False

# %%
# display rows where index is max for each speaker
speaker_rep4.loc[speaker_rep4.groupby('playerId')['chat_idx'].idxmax()]
# Out:
#        chat_idx             row_id  index  \
# 11513     11513  NYCaq7MRjWXmKTkuA     63
# 3796       3796  RcpAQ48MYLi4HrKJN     70
# 589         589  8EFd4pNoJkG3bH9PT     63
# 7139       7139  SHDxGmDT49fei3fQe     62
# 6529       6529  iFP5fLzy25sF6i7Gv     63
# 7464       7464  NnsZcTyTNrzosW2Sy     62
# 11375     11375  am2CTBc9obNm4apjA     60
# 415         415  L8T5vtE4uH5bSzZjs     60
# 4699       4699  N23TR9nkgNxFPPFgc     71
# 782         782  nXQdJ7oqL7nzk5G4B     64
# 4973       4973  43npkA3XeSNXEshuq     65
# 5262       5262  HALkjSJQf9zBRKDji     68
# 239         239  FrYMnCz7oPKHpEcKK     65
# 3475       3475  za6gwcTWPTfsftd8e     64
# 4131       4131  uBvYFXsSmCnDPrsza     67
# 7653       7653  LoDj6ngHNDvZFDv6K     62
# 11631     11631  vSfj8B72T2y8HKMYt     69
# 6802       6802  kTHzpNBLBciJWvS9Q     61
# 11181     11181  tBoY5riWzToEpvvqP     70
#
#                                   stageIds             gameId  \
# 11513  PTe3Yrce9hyNFTCnH,XeWxB2kwjyzDNnxbd  hhTtzgf2BMCbDwG5i
# 3796   mBLEhS2cpuuqpQ7jL,a7yuPoTp95kQMMu7t  kBQMXHtyqWiM2LxL6
# 589    zC4LYadRHgBtYBPEe,4E2Rsu9xK4t6qbiJQ  cA2SjWv3CePYZgyzS
# 589                                       on their knees  KDECwB9Cikjj7ZsE9
# 7139                             right angle on the left  PTgQgdtPBpeZAgKSJ
# 6529   on their knees with a triangle pointing to the...  Y3ATEvaw2Ex9TyTaM
# 7464                               arms out to the right  YisDn9qApPgZZysmj
# 11375                                        Legs behind  Za93y7uusM9q8x2fY
# 415                                     kneeling speaker  ZvhRyXkvKz6ES5HwX
# 4699                                     pointed upwards  aWXqkafSBD9Ty7ZCa
# 782      kneeling heals up at the back, triangle on back  c9T7t2RNEHdtaipbh
# 4973                        hands and knees facing right  f4yCdS7r3GCeu2Jan
# 5262   facing right, praying position, feet pointed u...  fnpWjeJ5eoBme4DLX
# 239                                                 duck  ieBYKaxXNCy2QcwJj
# 3475      person kneeling to right this time with a tail  kLzigdBtkD7wevtco
# 4131         fully knelt, triangle sticking up from left  mKtcij3NPdyCXiLFo
# 7653                                       arms held out  tSSE6WrrX5B6873NB
# 11631                        kneeling with tray on right  tnNKrEsyuarajKSEw
# 6802                                       two triangles  wzhhQtjp6x8rGAv7f
# 11181  like a person in a robe kneeling to the right,...  zfkDAvY8mpzxyfDYN
#
#                           target     role  countCorrect            speaker  \
# 11513  /experiment/tangram_K.png  speaker           2.0  CYJgWvH9gDvTupk6Y
# 3796   /experiment/tangram_K.png  speaker           3.0  DJMWzKpmH3hrQTzWH
# 589    /experiment/tangram_K.png  speaker           3.0  KDECwB9Cikjj7ZsE9
# 7139   /experiment/tangram_K.png  speaker           2.0  PTgQgdtPBpeZAgKSJ
# 6529   /experiment/tangram_K.png  speaker           3.0  Y3ATEvaw2Ex9TyTaM
# 7464   /experiment/tangram_K.png  speaker           3.0  YisDn9qApPgZZysmj
# 11375  /experiment/tangram_K.png  speaker           3.0  Za93y7uusM9q8x2fY
# 415    /experiment/tangram_K.png  speaker           3.0  ZvhRyXkvKz6ES5HwX
# 4699   /experiment/tangram_K.png  speaker           3.0  aWXqkafSBD9Ty7ZCa
# 782    /experiment/tangram_K.png  speaker           3.0  c9T7t2RNEHdtaipbh
# 4973   /experiment/tangram_K.png  speaker           3.0  f4yCdS7r3GCeu2Jan
# 5262   /experiment/tangram_K.png  speaker           2.0  fnpWjeJ5eoBme4DLX
# 239    /experiment/tangram_K.png  speaker           3.0  ieBYKaxXNCy2QcwJj
# 3475   /experiment/tangram_K.png  speaker           3.0  kLzigdBtkD7wevtco
# 4131   /experiment/tangram_K.png  speaker           3.0  mKtcij3NPdyCXiLFo
# 7653   /experiment/tangram_K.png  speaker           3.0  tSSE6WrrX5B6873NB
# 11631  /experiment/tangram_K.png  speaker           2.0  tnNKrEsyuarajKSEw
# 6802   /experiment/tangram_K.png  speaker           2.0  wzhhQtjp6x8rGAv7f
# 11181  /experiment/tangram_K.png  speaker           2.0  zfkDAvY8mpzxyfDYN
#
#       submitted                                       spellchecked is.chitchat
# 11513      True                              Begging facing right.       False
# 3796       True                       diamond head on diamond body       False
# 589        True                                     on their knees       False
# 7139       True                            right angle on the left       False
# 6529       True  on their knees with a triangle pointing to the...       False
# 7464       True                              arms out to the right       False
# 11375      True                                        Legs behind       False
# 415        True                                   kneeling speaker       False
# 4699       True                                    pointed upwards       False
# 782        True    kneeling heals up at the back, triangle on back       False
# 4973       True                       hands and knees facing right       False
# 5262       True  facing right, praying position, feet pointed u...       False
# 239        True                                               duck       False
# 3475       True     person kneeling to right this time with a tail       False
# 4131       True        fully knelt, triangle sticking up from left       False
# 7653       True                                      arms held out       False
# 11631      True                        kneeling with tray on right       False
# 6802       True                                      two triangles       False
# 11181      True  like a person in a robe kneeling to the right,...       False

# %% [markdown]
# Filter chat with certain game IDs to see what the whole convos look like

# %%
chat[(chat["gameId"] == "kBQMXHtyqWiM2LxL6") & (chat["repNum"] == 4) & (chat["target"] == "/experiment/tangram_D.png")]
# Out:
#       chat_idx             row_id  index                             stageIds  \
# 3764      3764  f2EMB869hRvzcib4v     50  FGYJZWNPMtXLAjvwe,Aeaqd68pxZoSojjBt
# 3765      3765  f2EMB869hRvzcib4v     50  FGYJZWNPMtXLAjvwe,Aeaqd68pxZoSojjBt
#
#                  gameId             createdAt  targetNum  repNum  trialNum  \
# 3764  kBQMXHtyqWiM2LxL6  2021-05-07T19:00:35Z          2       4        50
# 3765  kBQMXHtyqWiM2LxL6  2021-05-07T19:00:35Z          2       4        50
#
#       numPlayers                text           playerId  \
# 3764           4  Priest facing left  mkAas2g8EXQG9qda2
# 3765           4       On a roll now  HSh4jWAzERXqJPLFi
#
#                          target      role  countCorrect            speaker  \
# 3764  /experiment/tangram_D.png   speaker           2.0  mkAas2g8EXQG9qda2
# 3765  /experiment/tangram_D.png  listener           2.0  mkAas2g8EXQG9qda2
#
#      submitted        spellchecked is.chitchat
# 3764      True  Priest facing left       False
# 3765      True                 NaN        True

# %%
chat[(chat["gameId"] == "BXWWg9XvCErxTpT9k") & (chat["target"] == "/experiment/tangram_A.png")]
# Out:
#      chat_idx             row_id  index                             stageIds  \
# 607       607  JtdiCRJAvdx23syGv      1  Q3A34xL8vnB8yTye3,QcCX95DB93hjW7Xxu
# 608       608  JtdiCRJAvdx23syGv      1  Q3A34xL8vnB8yTye3,QcCX95DB93hjW7Xxu
# 609       609  JtdiCRJAvdx23syGv      1  Q3A34xL8vnB8yTye3,QcCX95DB93hjW7Xxu
# 610       610  JtdiCRJAvdx23syGv      1  Q3A34xL8vnB8yTye3,QcCX95DB93hjW7Xxu
# 611       611  JtdiCRJAvdx23syGv      1  Q3A34xL8vnB8yTye3,QcCX95DB93hjW7Xxu
# 612       612  JtdiCRJAvdx23syGv      1  Q3A34xL8vnB8yTye3,QcCX95DB93hjW7Xxu
# 695       695  fWFqQpdP4gHYjdkPN     20  qyF3z3ZSq6DduRX5u,3rJxwGz9XRXgpuve8
# 696       696  fWFqQpdP4gHYjdkPN     20  qyF3z3ZSq6DduRX5u,3rJxwGz9XRXgpuve8
# 704       704  Mw767nBLwrJZ5NYEB     25  qQRJkJKrqczkdybry,Mmgt5NWGrJzkHmWSC
# 705       705  Mw767nBLwrJZ5NYEB     25  qQRJkJKrqczkdybry,Mmgt5NWGrJzkHmWSC
# 706       706  Mw767nBLwrJZ5NYEB     25  qQRJkJKrqczkdybry,Mmgt5NWGrJzkHmWSC
# 738       738  kLaJ2wJp4RYT5TZYc     40  sDH8SScbhFQoon6z6,wtZR4fBAjwtmoFbsi
# 739       739  kLaJ2wJp4RYT5TZYc     40  sDH8SScbhFQoon6z6,wtZR4fBAjwtmoFbsi
# 758       758  92TYfpzhASTQLAQir     52  B9tt3iwNTZjXwxsWG,u2FYJdqBDHhmF5K3K
# 794       794  kRnnAapriBQzTFwE5     71  qcASrH8JomdidKwTY,RukbTRbgaBBi9sKeG
#
#                 gameId             createdAt  targetNum  repNum  trialNum  \
# 607  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       0         1
# 608  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       0         1
# 609  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       0         1
# 610  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       0         1
# 611  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       0         1
# 612  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       0         1
# 695  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          8       1        20
# 696  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          8       1        20
# 704  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       2        25
# 705  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       2        25
# 706  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          1       2        25
# 738  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          4       3        40
# 739  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          4       3        40
# 758  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z          4       4        52
# 794  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z         11       5        71
#
#      numPlayers                                               text  \
# 607           4                    Similar to the karate kid movie
# 608           4                                     the crane kick
# 609           4  Haha! Does it look like they have dangly sleeves!
# 610           4                             I don't know that one.
# 611           4                                                yes
# 612           4               yes i see, thats a good explenation.
# 695           4  Crane kick again, face is like a beak, it is t...
# 696           4                                 Or dangly sleeves?
# 704           4                    Dangly sleeves up opposite head
# 705           4                                Standing on one leg
# 706           4                                             Thanks
# 738           4  crane kick / beak face / one leg slighty raise...
# 739           4                                   say no more boss
# 758           4                                         crane kick
# 794           4                                         crane kick
#
#               playerId                     target      role  countCorrect  \
# 607  2Rs4BqzSBpqDh2fpP  /experiment/tangram_A.png   speaker           2.0
# 608  2Rs4BqzSBpqDh2fpP  /experiment/tangram_A.png   speaker           2.0
# 609  BHm7hWNhNRnqXSyJX  /experiment/tangram_A.png  listener           2.0
# 610  FzbGtMkbEZkg6xLHp  /experiment/tangram_A.png  listener           2.0
# 611  2Rs4BqzSBpqDh2fpP  /experiment/tangram_A.png   speaker           2.0
# 612  c9T7t2RNEHdtaipbh  /experiment/tangram_A.png  listener           2.0
# 695  c9T7t2RNEHdtaipbh  /experiment/tangram_A.png   speaker           2.0
# 696  BHm7hWNhNRnqXSyJX  /experiment/tangram_A.png  listener           2.0
# 704  FzbGtMkbEZkg6xLHp  /experiment/tangram_A.png   speaker           3.0
# 705  FzbGtMkbEZkg6xLHp  /experiment/tangram_A.png   speaker           3.0
# 706  BHm7hWNhNRnqXSyJX  /experiment/tangram_A.png  listener           3.0
# 738  BHm7hWNhNRnqXSyJX  /experiment/tangram_A.png   speaker           3.0
# 739  c9T7t2RNEHdtaipbh  /experiment/tangram_A.png  listener           3.0
# 758  2Rs4BqzSBpqDh2fpP  /experiment/tangram_A.png   speaker           3.0
# 794  c9T7t2RNEHdtaipbh  /experiment/tangram_A.png   speaker           3.0
#
#                speaker submitted  \
# 607  2Rs4BqzSBpqDh2fpP      True
# 608  2Rs4BqzSBpqDh2fpP      True
# 609  2Rs4BqzSBpqDh2fpP      True
# 610  2Rs4BqzSBpqDh2fpP      True
# 611  2Rs4BqzSBpqDh2fpP      True
# 612  2Rs4BqzSBpqDh2fpP      True
# 695  c9T7t2RNEHdtaipbh      True
# 696  c9T7t2RNEHdtaipbh      True
# 704  FzbGtMkbEZkg6xLHp      True
# 705  FzbGtMkbEZkg6xLHp      True
# 706  FzbGtMkbEZkg6xLHp      True
# 738  BHm7hWNhNRnqXSyJX      True
# 739  BHm7hWNhNRnqXSyJX      True
# 758  2Rs4BqzSBpqDh2fpP      True
# 794  c9T7t2RNEHdtaipbh      True
#
#                                           spellchecked is.chitchat
# 607                    Similar to the karate kid movie       False
# 608                                     the crane kick       False
# 609  Haha! Does it look like they have dangly sleeves!       False
# 610                                                NaN        True
# 611                                                NaN        True
# 612                                                NaN        True
# 695  Crane kick again, face is like a beak, it is t...       False
# 696                                 Or dangly sleeves?       False
# 704                    Dangly sleeves up opposite head       False
# 705                                Standing on one leg       False
# 706                                                NaN        True
# 738  crane kick / beak face / one leg slightly rais...       False
# 739                                                NaN        True
# 758                                         crane kick       False
# 794                                         crane kick       False

# %% [markdown]
# TODO: find the largest trial num for each referent participant pair etc

# %%
test_game = chat[(chat['gameId'] == "3WzEi9zkHF77vdTw5") & (chat['targetNum'] == 1) & (chat['repNum'] <= 4)]
test_game.head()
# Out:
#               row_id  index                             stageIds  \
# 3  tywCoAdX8FZS6pxkb      1  c2iyJTYwsrXsGAGfL,LXoXMwkLzxoyR3Pfk
# 4  tywCoAdX8FZS6pxkb      1  c2iyJTYwsrXsGAGfL,LXoXMwkLzxoyR3Pfk
# 5  tywCoAdX8FZS6pxkb      1  c2iyJTYwsrXsGAGfL,LXoXMwkLzxoyR3Pfk
# 6  tywCoAdX8FZS6pxkb      1  c2iyJTYwsrXsGAGfL,LXoXMwkLzxoyR3Pfk
# 7  tywCoAdX8FZS6pxkb      1  c2iyJTYwsrXsGAGfL,LXoXMwkLzxoyR3Pfk
#
#               gameId             createdAt  targetNum  repNum  trialNum  \
# 3  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          1       0         1
# 4  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          1       0         1
# 5  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          1       0         1
# 6  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          1       0         1
# 7  3WzEi9zkHF77vdTw5  2021-05-04T21:45:59Z          1       0         1
#
#    numPlayers                                               text  \
# 3           4  ok so its like a guy sort of crouching with hi...
# 4           4               idk how to describe stuff good sorry
# 5           4                              facing right or left?
# 6           4                                              right
# 7           4  like 2 rhombuses on the bottom with a square o...
#
#             playerId                     target      role  countCorrect  \
# 3  qZYMtuyj2SBfZk8XH  /experiment/tangram_L.png   speaker           3.0
# 4  qZYMtuyj2SBfZk8XH  /experiment/tangram_L.png   speaker           3.0
# 5  wXsGgzkQgoofFhxwk  /experiment/tangram_L.png  listener           3.0
# 6  qZYMtuyj2SBfZk8XH  /experiment/tangram_L.png   speaker           3.0
# 7  qZYMtuyj2SBfZk8XH  /experiment/tangram_L.png   speaker           3.0
#
#              speaker submitted  \
# 3  qZYMtuyj2SBfZk8XH      True
# 4  qZYMtuyj2SBfZk8XH      True
# 5  qZYMtuyj2SBfZk8XH      True
# 6  qZYMtuyj2SBfZk8XH      True
# 7  qZYMtuyj2SBfZk8XH      True
#
#                                         spellchecked is.chitchat
# 3  ok so it's like a guy sort of crouching with h...       False
# 4                                                NaN        True
# 5                              facing right or left?       False
# 6                                              right       False
# 7  like 2 rhombuses on the bottom with a square o...       False

# %% [markdown]
# TODOS:
# - FIgure out which index is which tangram
# - Figure out how to get to the end of a conversation (is it the last trialnum, for a certain target, for the speaker, that is NOT chitchat?)
#   - Oh wait it should be at the end of round 3, what does the speaker refer to, then use the whole conversation history for THAST TANGRAM at the end of round 3..
#   - Should we keep `repnum` constant (i.e. make it correspond to the actual `repnum` in what we show participants?)
#
# Take repnum = 4, speaker, and for the game get all conversations ABOUT THAT TANSGRAM in different reps
#
# It doesnt fully give you the actual order of what people said? So we have to infer it from row order? See how veronica does this. Maybe add a column for order of utterance for each tangram
#
# Load round results and round include RDS file to figure out what is going on there
#
# The chosen orund results are in the `round_results` file, however the chat info should ALSO have the time stamps, how to figure out how to load it in

# %%
response_data = pd.read_csv('../tangram_data/round_results.csv')

# %%
response_data[(response_data['target'] == '/experiment/tangram_K.png') & (response_data['gameId'] == 'BXWWg9XvCErxTpT9k')].sort_index()
# Out:
#                    _id  index                             stageIds  \
# 648  AMhgWE6mGuEjsrqAT     12  hNxtt8XXxbjxyM3cY,YwMQkBPcf4oFGsj4r
# 660  LBZjbRQXapAzjNfjP     24  mjT5eFn3NXXiC75Fd,5zNjD4KDAQ7XLzuAX
# 681  PDWtAcwnC2NPB4PgP     45  cxDv5jqqfTp2W3AjT,bTpA4ZCH9rBxHeib4
# 688  nXQdJ7oqL7nzk5G4B     64  iGDWogxxDQy9CZHWG,WdBKZ4tMjWw2uEvKX
# 700  BRGrEnpjeZwE2PAeG      4  QtMPaGTFPxQNpt2TY,xaF7QwFLCNNtYC8d9
# 708  AMhgWE6mGuEjsrqAT     12  hNxtt8XXxbjxyM3cY,YwMQkBPcf4oFGsj4r
# 720  LBZjbRQXapAzjNfjP     24  mjT5eFn3NXXiC75Fd,5zNjD4KDAQ7XLzuAX
# 732  riAq2ezXrjptRTTtJ     48  NkM64W7uz7BrFCH4W,pWL9xLg4CJvPd2pLk
# 748  nXQdJ7oqL7nzk5G4B     64  iGDWogxxDQy9CZHWG,WdBKZ4tMjWw2uEvKX
# 760  BRGrEnpjeZwE2PAeG      4  QtMPaGTFPxQNpt2TY,xaF7QwFLCNNtYC8d9
# 768  AMhgWE6mGuEjsrqAT     12  hNxtt8XXxbjxyM3cY,YwMQkBPcf4oFGsj4r
# 789  PDWtAcwnC2NPB4PgP     45  cxDv5jqqfTp2W3AjT,bTpA4ZCH9rBxHeib4
# 792  riAq2ezXrjptRTTtJ     48  NkM64W7uz7BrFCH4W,pWL9xLg4CJvPd2pLk
# 808  nXQdJ7oqL7nzk5G4B     64  iGDWogxxDQy9CZHWG,WdBKZ4tMjWw2uEvKX
# 820  BRGrEnpjeZwE2PAeG      4  QtMPaGTFPxQNpt2TY,xaF7QwFLCNNtYC8d9
# 828  LBZjbRQXapAzjNfjP     24  mjT5eFn3NXXiC75Fd,5zNjD4KDAQ7XLzuAX
# 849  PDWtAcwnC2NPB4PgP     45  cxDv5jqqfTp2W3AjT,bTpA4ZCH9rBxHeib4
# 852  riAq2ezXrjptRTTtJ     48  NkM64W7uz7BrFCH4W,pWL9xLg4CJvPd2pLk
#
#                 gameId             createdAt                     target  \
# 648  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 660  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 681  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 688  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 700  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 708  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 720  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 732  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 748  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 760  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 768  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 789  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 792  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 808  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 820  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 828  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 849  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
# 852  BXWWg9XvCErxTpT9k  2021-05-04T22:41:03Z  /experiment/tangram_K.png
#
#      targetNum  repNum  trialNum  numPlayers  countCorrect            speaker  \
# 648          0       1        12           4             3  c9T7t2RNEHdtaipbh
# 660          0       2        24           4             3  FzbGtMkbEZkg6xLHp
# 681          9       3        45           4             3  BHm7hWNhNRnqXSyJX
# 688          4       5        64           4             3  c9T7t2RNEHdtaipbh
# 700          4       0         4           4             2  2Rs4BqzSBpqDh2fpP
# 708          0       1        12           4             3  c9T7t2RNEHdtaipbh
# 720          0       2        24           4             3  FzbGtMkbEZkg6xLHp
# 732          0       4        48           4             2  2Rs4BqzSBpqDh2fpP
# 748          4       5        64           4             3  c9T7t2RNEHdtaipbh
# 760          4       0         4           4             2  2Rs4BqzSBpqDh2fpP
# 768          0       1        12           4             3  c9T7t2RNEHdtaipbh
# 789          9       3        45           4             3  BHm7hWNhNRnqXSyJX
# 792          0       4        48           4             2  2Rs4BqzSBpqDh2fpP
# 808          4       5        64           4             3  c9T7t2RNEHdtaipbh
# 820          4       0         4           4             2  2Rs4BqzSBpqDh2fpP
# 828          0       2        24           4             3  FzbGtMkbEZkg6xLHp
# 849          9       3        45           4             3  BHm7hWNhNRnqXSyJX
# 852          0       4        48           4             2  2Rs4BqzSBpqDh2fpP
#
#      submitted           playerId  correct                   response    time  \
# 648       True  2Rs4BqzSBpqDh2fpP     True  /experiment/tangram_K.png  40.335
# 660       True  2Rs4BqzSBpqDh2fpP     True  /experiment/tangram_K.png  28.152
# 681       True  2Rs4BqzSBpqDh2fpP     True  /experiment/tangram_K.png  16.876
# 688       True  2Rs4BqzSBpqDh2fpP     True  /experiment/tangram_K.png  20.413
# 700       True  BHm7hWNhNRnqXSyJX     True  /experiment/tangram_K.png  91.167
# 708       True  BHm7hWNhNRnqXSyJX     True  /experiment/tangram_K.png  45.326
# 720       True  BHm7hWNhNRnqXSyJX     True  /experiment/tangram_K.png  30.929
# 732       True  BHm7hWNhNRnqXSyJX     True  /experiment/tangram_K.png  37.375
# 748       True  BHm7hWNhNRnqXSyJX     True  /experiment/tangram_K.png  22.610
# 760       True  FzbGtMkbEZkg6xLHp    False  /experiment/tangram_L.png  68.704
# 768       True  FzbGtMkbEZkg6xLHp     True  /experiment/tangram_K.png  68.096
# 789       True  FzbGtMkbEZkg6xLHp     True  /experiment/tangram_K.png  35.481
# 792       True  FzbGtMkbEZkg6xLHp     True  /experiment/tangram_K.png  58.175
# 808       True  FzbGtMkbEZkg6xLHp     True  /experiment/tangram_K.png  42.756
# 820       True  c9T7t2RNEHdtaipbh     True  /experiment/tangram_K.png  69.290
# 828       True  c9T7t2RNEHdtaipbh     True  /experiment/tangram_K.png  38.175
# 849       True  c9T7t2RNEHdtaipbh     True  /experiment/tangram_K.png  12.443
# 852       True  c9T7t2RNEHdtaipbh     True  /experiment/tangram_K.png  48.640
#
#     tangram  realCorrect
# 648       K            3
# 660       K            3
# 681       K            3
# 688       K            3
# 700       K            2
# 708       K            3
# 720       K            3
# 732       K            3
# 748       K            3
# 760       K            2
# 768       K            3
# 789       K            3
# 792       K            3
# 808       K            3
# 820       K            2
# 828       K            3
# 849       K            3
# 852       K            3

# %%
import random
import re

def extract_letter(tangram_path: str) -> str:
    """extract letter from tangram path"""
    match = re.search(r'tangram_([A-Z])', tangram_path)
    if match:
        return match.group(1)
    return None


def get_convo_data(tangram, label, game, chat_data, response_data):
    """
    Given a target tangram and a game, extract the convo data for each rep
    (make sure to rename the players to alice, bob, carol, dave, etc.)
    Output should be in the format of, e.g.,
        {
        "target": "C",
        "convention": "crane kick",
        "game": "xxx",
        "rep": 0,
        "speakerThisRep": "alice",
        "convo": [{"player": "xxx", "text": "sample", "time": 2, "role": "speaker"}],
        "choices": {"bob": "B", "carol": "C", "dave": "B"}
    }
    (there should be one element per rep)
    """
    chat = chat_data[
        (chat_data["gameId"] == game)
        & (chat_data["target"] == f"/experiment/tangram_{tangram}.png")
    ]
    response = response_data[
        (response_data["gameId"] == game)
        & (response_data["target"] == f"/experiment/tangram_{tangram}.png")
    ]

    # rename the playerIds
    # rename the speaker at rep 0 to alice, rep 1 to bob, rep 2 to carol, rep 3 to dave
    rename_mappings = {}
    for participant in chat["playerId"].unique():
        speaker_rep_num = chat[chat["speaker"] == participant]["repNum"].unique()[0]
        speaker_rep_num = (
            speaker_rep_num % 4
        )  # dont necessarily need to do this, but just in case
        rename_mappings[participant] = ["alice", "bob", "carol", "dave"][
            speaker_rep_num
        ]

    # rename the playerIds in the chat data
    for participant in rename_mappings:
        chat.loc[chat["playerId"] == participant, "playerId"] = rename_mappings[participant]
        chat.loc[chat["speaker"] == participant, "speaker"] = rename_mappings[participant]

    # rename the playerIds in the response data
    for participant in rename_mappings:
        response.loc[response["playerId"] == participant, "playerId"] = rename_mappings[participant]

    # for each rep num, make convo
    output = []
    for rep in chat["repNum"].unique():
        rep_chat = chat[chat["repNum"] == rep]
        convo = []

        # extract convo data
        for idx, row in rep_chat.iterrows():
            convo.append(
                {
                    "player": row["playerId"],
                    "text": row["text"],
                    "time": random.uniform(0.5, 1.5),
                    "role": row["role"],
                }
            )

        # extract choices
        choices = response[(response["repNum"] == rep)]
        choices = {row["playerId"]: extract_letter(row["response"]) for idx, row in choices.iterrows()}
        output.append(
            {
                "target": tangram,
                "convention": label,
                "game": game,
                "repNum": rep,
                "speakerThisRep": rep_chat['speaker'].unique()[0],
                "convo": convo,
                "choices": choices,
            }
        )

    return output

# %%
test_convo = get_convo_data('A', 'crane kick', 'BXWWg9XvCErxTpT9k', chat, response_data)

# %%
test_convo
# Out:
# [{'target': 'A',
#   'convention': 'crane kick',
#   'game': 'BXWWg9XvCErxTpT9k',
#   'repNum': 0,
#   'speakerThisRep': 'alice',
#   'convo': [{'player': 'alice',
#     'text': 'Similar to the karate kid movie',
#     'time': 0.6737561695407466,
#     'role': 'speaker'},
#    {'player': 'alice',
#     'text': 'the crane kick',
#     'time': 1.290651702755922,
#     'role': 'speaker'},
#    {'player': 'dave',
#     'text': 'Haha! Does it look like they have dangly sleeves!',
#     'time': 1.0528834538444625,
#     'role': 'listener'},
#    {'player': 'carol',
#     'text': "I don't know that one.",
#     'time': 0.7826106422805829,
#     'role': 'listener'},
#    {'player': 'alice',
#     'text': 'yes',
#     'time': 1.1240242919956662,
#     'role': 'speaker'},
#    {'player': 'bob',
#     'text': 'yes i see, thats a good explenation.',
#     'time': 1.1682977753231745,
#     'role': 'listener'}],
#   'choices': {'dave': 'A', 'carol': 'I', 'bob': 'A'}},
#  {'target': 'A',
#   'convention': 'crane kick',
#   'game': 'BXWWg9XvCErxTpT9k',
#   'repNum': 1,
#   'speakerThisRep': 'bob',
#   'convo': [{'player': 'bob',
#     'text': 'Crane kick again, face is like a beak, it is the only one which has a triangle beak face',
#     'time': 0.8791003986131217,
#     'role': 'speaker'},
#    {'player': 'dave',
#     'text': 'Or dangly sleeves?',
#     'time': 1.0359790547491705,
#     'role': 'listener'}],
#   'choices': {'alice': 'A', 'dave': 'A', 'carol': 'G'}},
#  {'target': 'A',
#   'convention': 'crane kick',
#   'game': 'BXWWg9XvCErxTpT9k',
#   'repNum': 2,
#   'speakerThisRep': 'carol',
#   'convo': [{'player': 'carol',
#     'text': 'Dangly sleeves up opposite head',
#     'time': 0.8009584559761167,
#     'role': 'speaker'},
#    {'player': 'carol',
#     'text': 'Standing on one leg',
#     'time': 0.9754871713468451,
#     'role': 'speaker'},
#    {'player': 'dave',
#     'text': 'Thanks',
#     'time': 1.4736339206076825,
#     'role': 'listener'}],
#   'choices': {'alice': 'A', 'dave': 'A', 'bob': 'A'}},
#  {'target': 'A',
#   'convention': 'crane kick',
#   'game': 'BXWWg9XvCErxTpT9k',
#   'repNum': 3,
#   'speakerThisRep': 'dave',
#   'convo': [{'player': 'dave',
#     'text': 'crane kick / beak face / one leg slighty raised in front',
#     'time': 1.0163429419697065,
#     'role': 'speaker'},
#    {'player': 'bob',
#     'text': 'say no more boss',
#     'time': 1.1566272790186996,
#     'role': 'listener'}],
#   'choices': {'alice': 'A', 'carol': 'A', 'bob': 'A'}},
#  {'target': 'A',
#   'convention': 'crane kick',
#   'game': 'BXWWg9XvCErxTpT9k',
#   'repNum': 4,
#   'speakerThisRep': 'alice',
#   'convo': [{'player': 'alice',
#     'text': 'crane kick',
#     'time': 1.3734944389812527,
#     'role': 'speaker'}],
#   'choices': {'dave': 'A', 'carol': 'A', 'bob': 'A'}},
#  {'target': 'A',
#   'convention': 'crane kick',
#   'game': 'BXWWg9XvCErxTpT9k',
#   'repNum': 5,
#   'speakerThisRep': 'bob',
#   'convo': [{'player': 'bob',
#     'text': 'crane kick',
#     'time': 0.5211030719306226,
#     'role': 'speaker'}],
#   'choices': {'alice': 'A', 'dave': 'A', 'carol': 'A'}}]

# %%
import json
import numpy as np

# Convert int64 values to regular integers
def convert_int64(obj):
    if isinstance(obj, np.int64):
        return int(obj)
    return obj

# Save to JSON with converted int64 values
with open('test_convo.json', 'w') as f:
    json.dump(test_convo, f, default=convert_int64)
