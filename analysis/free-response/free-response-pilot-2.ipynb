# %% [markdown]
# # Free response pilot 2
#
# July 15, 2025

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

plt.rcParams.update({'font.size': 16})

# %%
data_dir = "../../../data/3pp/free-response/"

data = pd.read_csv(data_dir + "selection_trials.csv")
demographics = pd.read_csv(data_dir + "exit_survey.csv")

data["prop_naive"] = data["n_naive"] / (data["n_naive"] + data["n_blue"])

data.head(10)
# Out:
#                  subject_id  item_id counterbalance  trial_num  n_blue  \
# 0  648343299ec8050d10aee27d        1              a          0       1
# 1  648343299ec8050d10aee27d        1              a          1       3
# 2  648343299ec8050d10aee27d        1              a          2       1
# 3  648343299ec8050d10aee27d        1              a          3       1
# 4  648343299ec8050d10aee27d        1              a          4       2
# 5  648343299ec8050d10aee27d        1              a          5       3
# 6  648343299ec8050d10aee27d        1              a          6       1
# 7  648343299ec8050d10aee27d        1              a          7       2
# 8  648343299ec8050d10aee27d        1              a          8       3
# 9  648343299ec8050d10aee27d        1              a          9       4
#
#    n_naive    goal previous_selection selected_tangram selected_tangram_group  \
# 0        4   refer                NaN                C                 shared
# 1        2  social                  C                B                 shared
# 2        0   refer                  B                D                 shared
# 3        2   refer                  D                H           red_specific
# 4        8   refer                  H                K          blue_specific
# 5        8   refer                  K                I          blue_specific
# 6        0  social                  I                A                 shared
# 7        0   refer                  A                B                 shared
# 8        2   refer                  B                F           red_specific
# 9        4  social                  F                J          blue_specific
#
#    ...                      selected_tangram_earlier_blue  \
# 0  ...  Looks like a man raising both hands into the a...
# 1  ...  the person is kneeling with their hands strech...
# 2  ...  this looks like a standing person with a trian...
# 3  ...                                                NaN
# 4  ...  its a diamond on a diamond with a triangle out...
# 5  ...  the one that looks like a standing person with...
# 6  ...  Similar to the karate kid movie, the crane kic...
# 7  ...  the person is kneeling with their hands strech...
# 8  ...                                                NaN
# 9  ...  the image where there is it has a cube (i.e. t...
#
#   selected_tangram_later_red selected_tangram_later_blue  \
# 0                    italian                       shrug
# 1                      mouse              princess dance
# 2                     priest           long sleeved book
# 3           the innocent one                         NaN
# 4                        NaN                        duck
# 5                        NaN                    yoga guy
# 6                   thriller                  crane kick
# 7                      mouse              princess dance
# 8                        sad                         NaN
# 9                        NaN                  large cube
#
#                                        written_label  \
# 0  diamond head long body looks like they are fal...
# 1                                     Princess dance
# 2  looks like a priest with long sleeves holding ...
# 3   diamond head long body slight point to the right
# 4  kind of looks like a duck with a diamond on it...
# 5  diamond head arms to the left one leg down kic...
# 6                            looks like a crane kick
# 7  diamond head looks like squat body with arms s...
# 8  looks like someone sitting down leaning back l...
# 9  cube body diamond on top attached to the cube ...
#
#   sbert_cosine_earlier_blue  sbert_cosine_earlier_red  \
# 0                  0.363582                  0.478463
# 1                  0.188083                  0.144821
# 2                  0.572890                  0.613260
# 3                       NaN                  0.561179
# 4                  0.699207                       NaN
# 5                  0.560457                       NaN
# 6                  0.690420                  0.191722
# 7                  0.561347                  0.626889
# 8                       NaN                  0.766449
# 9                  0.614340                       NaN
#
#    sbert_cosine_later_blue  sbert_cosine_later_red  utt_length  prop_naive
# 0                 0.095969                0.137895          13    0.800000
# 1                 1.000000                0.058624           2    0.400000
# 2                 0.493653                0.628414          13    0.000000
# 3                      NaN                0.076040           9    0.666667
# 4                 0.639732                     NaN          12    0.800000
# 5                 0.278519                     NaN          16    0.727273
# 6                 0.872998                0.044447           5    0.000000
# 7                 0.276264                0.021161          24    0.000000
# 8                      NaN                0.238704          11    0.400000
# 9                 0.584301                     NaN          12    0.500000
#
# [10 rows x 21 columns]

# %%
sns.violinplot(x="goal", y="utt_length", hue="goal", data=data)
sns.despine()

# %%
g = sns.pointplot(
    x="prop_naive", y="utt_length", hue="goal", data=data, native_scale=True, dodge=0.4
)
g.set_xlabel("Proportion naive")
g.set_ylabel("Utterance length")
sns.despine()

# %%
g = sns.pointplot(
    x="prop_naive", y="sbert_cosine_later_blue", hue="goal", data=data, native_scale=True, dodge=0.4
)
g.set_xlabel("Proportion naive")
g.set_ylabel("Cosine similarity to later blue")
g.set_ylim(0, 1)
sns.despine()

# %%
# Filter to only blue tangrams
filtered_data = data[(data["selected_tangram_group"] == "blue_specific") | (data["selected_tangram_group"] == "shared")]

# Plot cosine similarity to later blue
g = sns.pointplot(
    x="prop_naive", y="sbert_cosine_later_blue", hue="goal", data=filtered_data, native_scale=True, dodge=0.4
)
g.set_xlabel("Proportion naive")
g.set_ylabel("Cosine similarity to later blue")
g.set_ylim(0, 1)
g.set_title("Only blue-group tangrams")
sns.despine()

# %%
g = sns.pointplot(
    x="prop_naive", y="sbert_cosine_earlier_blue", hue="goal", data=data, native_scale=True, dodge=0.4
)
g.set_xlabel("Proportion naive")
g.set_ylabel("Cosine similarity to earlier blue")
g.set_ylim(0, 1)
sns.despine()

# %%
g = sns.pointplot(
    x="prop_naive", y="sbert_cosine_earlier_red", hue="goal", data=data, native_scale=True, dodge=0.4
)
g.set_xlabel("Proportion naive")
g.set_ylabel("Cosine similarity to earlier red")
g.set_ylim(0, 1)
sns.despine()

# %%
g = sns.pointplot(
    x="prop_naive", y="sbert_cosine_later_red", hue="goal", data=data, native_scale=True, dodge=0.4
)
g.set_xlabel("Proportion naive")
g.set_ylabel("Cosine similarity to later red")
g.set_ylim(0, 1)
sns.despine()

# %%
sns.histplot(
    x="prop_naive",
    hue="selected_tangram_group",
    hue_order=["shared", "blue_specific", "red_specific"], 
    multiple="fill",
    stat="probability",
    data=data[data["goal"] == "refer"]
)
plt.title("Refer")
plt.show()

# %%
sns.histplot(
    x="prop_naive",
    hue="selected_tangram_group",
    hue_order=["shared", "blue_specific", "red_specific"], 
    multiple="fill",
    stat="probability",
    data=data[data["goal"] == "social"]
)
plt.title("Social")
plt.show()
